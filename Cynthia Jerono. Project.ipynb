# %% [markdown]
# Microsoft Film Industry Analysis

# %% [markdown]
# ![Page Image](attachment:image.png)
#
# Source IMDB
#
# Disclaimer that the copyright owner is unknown.

# %% [markdown]
# Overview

# %% [markdown]
# As a result of the rise in original film production in mega companies, Microsoft has tasked us with the responsibility to appraise her of the movie industry outlook before it climbs on the bandwagon. We used the return on investment as a measure to gauge the profitability of particular gernres, previewed the month of release of those perticular movies, looked into the genres that were most popular and those that had high viewer votes so we could come up with conclusions.

# %% [markdown]
# 1. Business Problem

# %% [markdown]
# Due to the increase in original film production by major companies, Microsoft has tasked us with evaluating the movie industry outlook before it joins the trend. We used the return on investment to assess the profitability of specific genres, analyzed the release months of those movies, and examined the genres that were most popular and received high viewer ratings. These analyses will help us draw informed conclusions.

# %% [markdown]
# The potential business challenge for Microsoft in entering the original video content space lies in figuring out how to create content that stands out from competitors and attracts and retains viewers. With established players like Sony and Disney already producing exceptional original content, Microsoft will need to differentiate itself and create compelling content that resonates with audiences. To gain a foothold in the market, Microsoft should:
#
# * Identify top five movies with the highest world wide gross
# * Find the average total domestic gross per annum.
# * Find the Production budget for the top five highest earning movies

# %%
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os

# %% [markdown]
# 1. Data Understanding

# %% [markdown]
#         In this section, we will:
#
# 1. Prepare the dataset from Box Office Mojo (Data\bom.movie_gross.csv), which includes data on movies that are performing well at the box office in terms of domestic and foreign earnings.
# 2. Process the data from review.tsv, which contains reviews of the box office movies.
# 3. Examine the budgets allocated for producing movies that are successful at the box office.

# %%
df = pd.read_csv('Data/bom.movie_gross.csv')
df.head() # Returns the first five rows from the datafame.
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
df['year'].value_counts()
# Out:
# 2015    450
# 2016    436
# 2012    399
# 2011    398
# 2014    394
# 2013    350
# 2010    327
# 2017    320
# 2018    308
# Name: year, dtype: int64

# %% [markdown]
# Returns a tuple representing the rows and columns of the  dataframe.

# %%
df.shape
# Out:
# (3387, 5)

# %% [markdown]
# To check a  summary of the df.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %% [markdown]
# ### 1.2) Read `Data\tn.movie_budgets.csv` into a pandas DataFrame named `budgets`
#
# We will use pandas to create a new DataFrame, called `budgets`, containing the data from the dataset in the file `Data\tn.movie_budgets.csv` in the folder containing this notebook.

# %%
budgets = pd.read_csv('Data/tn.movie_budgets.csv')
budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
budgets.shape
# Out:
# (5782, 6)

# %%
budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %% [markdown]
# ###Looking at the provided code block, it's evident that there are discrepancies in the counts of Non-Null values, indicating the presence of missing data. We'll address this issue in Part 2 during the Data Preparation phase.

# %% [markdown]
# # Part 2: Data Preparation
# In this part, we will clean and transform the data. This includes handling missing values, converting data types, filtering and more.
#
# ## 2.1: Data Preparation - Data\bom.movie_gross.csv**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3382 entries, 0 to 3386
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3382 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3356 non-null   float64
#  3   year            3382 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 132.1+ KB

# %%
df.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %% [markdown]
# ##### From the above code block, we can see that the studio column has 5 missing values, domestic gross has 28 missing values & foreign gross has 1350 missing values. Now that we know the missing values in each column, we can make decisions on how to deal with them.
#
# ##### In the cell below;
# - **Let's determine what percentage of rows in columns with missing values contain missing values.**
#
# - **Print out the number of unique values in the columns.**

# %%
print('Percentage of Null foreign_gross Values:', len(df[df.foreign_gross.isna()])/len(df))

print('Percentage of Null domestic_gross Values:', len(df[df.domestic_gross.isna()])/len(df))

print('Percentage of Null studio Values:', len(df[df.studio.isna()])/len(df))
# Out:
# Percentage of Null foreign_gross Values: 0.3985828166519043
# Percentage of Null domestic_gross Values: 0.008266902863891349
# Percentage of Null studio Values: 0.0014762326542663124

# %%
df.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
df = df.drop('foreign_gross', axis = 1)
df.isna().sum()
# Out:
# title              0
# studio             5
# domestic_gross    28
# year               0
# dtype: int64

# %%
domestic_gross_mean = df['domestic_gross'].mean()
domestic_gross_median = df['domestic_gross'].median()

print(f"Mean value for domestic  gross  column: {domestic_gross_mean}")
print(f"Median value for domestic gross column: {domestic_gross_median}")
# Out:
# Mean value for domestic grosscolumn: 28771489.56495828
# Median value for domestic gross column: 1400000.0

# %%
df['domestic_gross'].isna().sum()
# Out:
# 28

# %% [markdown]
# - **In the cell below, we will replace the missing values in the domestic gross column with the median value.**

# %%
df['domestic_gross'] = df['domestic_gross'].fillna(value=df['domestic_gross'].median)

# %%
df['domestic_gross']
# Out:
# 0        4.15e+08
# 1       3.342e+08
# 2        2.96e+08
# 3       2.926e+08
# 4       2.387e+08
#           ...
# 3382         6200
# 3383         4800
# 3384         2500
# 3385         2400
# 3386         1700
# Name: domestic_gross, Length: 3387, dtype: object

# %% [markdown]
# ##### Now let's confirm the missing values have been replaced and also check on the number of remaining null values in the dataset.

# %%
df.isna().sum()
# Out:
# title             0
# studio            5
# domestic_gross    0
# year              0
# dtype: int64

# %%
df = df.dropna()
df.isna().sum()
# Out:
# title             0
# studio            0
# domestic_gross    0
# year              0
# dtype: int64

# %%
df['domestic_gross'] = pd.to_numeric(df['domestic_gross'],errors='coerce')

# %% [markdown]
# ## 2.2: Data Preparation - Data\tn.movie_budgets.csv

# %%
budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
budgets.isna().sum()
# Out:
# id                   0
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %% [markdown]
# - **This dataset has no missing values. We will proceed to analyzing the data in Part 3. But first we need to remove the dollar signs and commas from monetary columns and convert them to numeric.**

# %%
monetary_cols = ['production_budget', 'domestic_gross', 'worldwide_gross']
for col in monetary_cols:
    budgets[col] = budgets[col].str.replace('$', '').str.replace(',', '').astype(float)

budgets['release_date'] = pd.to_datetime(budgets['release_date'])

# %% [markdown]
# # 3.Analyzing Data
# - **Here we are going to use .groupby method which will split the dataset into subgroups. This will help with comparison. We will have to chain aggregation functions on to the groupby to enable us to compute summary statistics.**

# %% [markdown]
# ### 3.1 Data Analysis - Data\bom.movie_gross.csv
# - **Here we will group our dataset by Studio that produce the movie, the year the movie was produced and the domestic gains for that year.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3382 entries, 0 to 3386
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3382 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3356 non-null   float64
#  3   year            3382 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 132.1+ KB

# %%
df.isna().sum()
# Out:
# title              0
# studio             0
# domestic_gross    26
# year               0
# dtype: int64

# %%
df.groupby(["studio", "year"])["domestic_gross"].sum()
# Out:
# studio  year
# 3D      2010     6100000.0
# A23     2011      151000.0
#         2013       13200.0
# A24     2013    27845400.0
#         2014    18988300.0
#                    ...
# Zeit.   2013      785000.0
#         2014      504700.0
#         2015       22900.0
#         2016       11700.0
#         2017      820000.0
# Name: domestic_gross, Length: 742, dtype: float64

# %%
df.groupby(["studio", "year"])["domestic_gross"].max().head() #This code helps in finding out the studios with the highest-grossing movies within each year. We've only considered only the top 5 results.
# Out:
# studio  year
# 3D      2010     6100000.0
# A23     2011      151000.0
#         2013       13200.0
# A24     2013    14100000.0
#         2014     5700000.0
# Name: domestic_gross, dtype: float64

# %%
yearly_domestic_gross = df.groupby('year')['domestic_gross'].sum() #We have grouped the years and calculated the total domestic gross for each year.

# %%
df.domestic_gross.iloc[:5] #retrieves the first 5 elements from the domestic gross column of the dataframe.
# Out:
# 0    415000000.0
# 1    334200000.0
# 2    296000000.0
# 3    292600000.0
# 4    238700000.0
# Name: domestic_gross, dtype: float64

# %% [markdown]
# ### 3.2 Data Analysis - Data\tn.movie_budgets.csv
# - **Here we will sum up the domestic gross and the worldwide gross then compare using descriptive analysis against the movie production budget.**

# %%
budgets['Total_gross'] = budgets['domestic_gross'] + budgets['worldwide_gross']
budgets['Total_gross'].head()
# Out:
# 0    3.536853e+09
# 1    1.286728e+09
# 2    1.925247e+08
# 3    1.862020e+09
# 4    1.936903e+09
# Name: Total_gross, dtype: float64

# %%
correlation = budgets[['production_budget', 'Total_gross']].corr()
correlation
# Out:
#                    production_budget  Total_gross
# production_budget           1.000000     0.739912
# Total_gross                 0.739912     1.000000

# %% [markdown]
# - ***Production budget and Total gross have a correlation of 0.739912 indicating a strong positive correlation. Movies with higher production budgets tend to have higher total gross incomes and vice versa.***
# - ****In the cell below, we will find the return on investments from the movies.****

# %%
budgets['ROI'] = (budgets['Total_gross']-budgets['production_budget'])/budgets['production_budget']

# %%
budgets['ROI'].describe()
# Out:
# count    5782.000000
# mean        6.783702
# std        54.922090
# min        -1.000000
# 25%        -0.202878
# 50%         1.659315
# 75%         4.893170
# max      3599.000000
# Name: ROI, dtype: float64

# %%
yearly_ROI = budgets.groupby('release_date')['ROI'].mean()

# %% [markdown]
# # 4. Data Visualization
# **Here we will use matplotlib and seaborn to visualize the data which will make it simpler for us to interpret.**

# %% [markdown]
# #### 4.1 Data Visualization - Data\bom.movie_gross.csv
# **We will plot the years the movies were released against the domestic income generated in that year.**

# %%
yearly_domestic_gross
# Out:
# year
# 2010    1.015683e+10
# 2011    1.006409e+10
# 2012    1.087661e+10
# 2013    1.079233e+10
# 2014    1.033773e+10
# 2015    1.105141e+10
# 2016    1.125365e+10
# 2017    1.093327e+10
# 2018    1.109121e+10
# Name: domestic_gross, dtype: float64

# %%
plt.figure(figsize=(15,8))
yearly_domestic_gross.plot(kind='bar', color='skyblue')
plt.title('A Bar Plot showing the Total Domestic  Gross by Year')
plt.xlabel('Year')
plt.ylabel('Total Domestic Gross')
plt.show()

# %% [markdown]
# #### From the above bar plot, we can see that the year in which the highest domestic gross income was generated was in 2016 where gross income from the movies was 11,253,653,097 dollars.

# %%
budgets.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross   Total_gross       ROI
# 0        425000000.0     760507625.0     2.776345e+09  3.536853e+09  7.322007
# 1        410600000.0     241063875.0     1.045664e+09  1.286728e+09  2.133774
# 2        350000000.0      42762350.0     1.497624e+08  1.925247e+08 -0.449929
# 3        330600000.0     459005868.0     1.403014e+09  1.862020e+09  4.632244
# 4        317000000.0     620181382.0     1.316722e+09  1.936903e+09  5.110105

# %%
budgets_df = budgets[['movie', 'production_budget', 'worldwide_gross']]

# %%
top_5_movies = budgets_df.sort_values(by='worldwide_gross', ascending=False).head()
top_5_movies
# Out:
#                                    movie  production_budget  worldwide_gross
# 0                                 Avatar        425000000.0     2.776345e+09
# 42                               Titanic        200000000.0     2.208208e+09
# 5   Star Wars Ep. VII: The Force Awakens        306000000.0     2.053311e+09
# 6                 Avengers: Infinity War        300000000.0     2.048134e+09
# 33                        Jurassic World        215000000.0     1.648855e+09

# %%
plt.figure(figsize=(15,8))
plt.bar(top_5_movies['movie'], top_5_movies['worldwide_gross'], color='skyblue')
plt.xlabel('Movie')
plt.ylabel('World Wide Gross')
plt.title('Worldwide gross earnings for Top 5 Movies')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# From our findings Avatar holds the lead in the Worldwide gross earnings.
# Jurassic world has the least World wide gross earnings in the least of five.

# %%
plt.figure(figsize=(15,8))
plt.bar(top_5_movies['movie'], top_5_movies['production_budget'], color='skyblue')
plt.xlabel('Movie')
plt.ylabel('Production Budget')
plt.title('Production Budget for Top 5 Movies highest earning Movies')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### From the two Bar graphs above, we can see that production budget of a movie plays a huge role in the amount of earnings a Movie will make. For instance, the movie Avatar had a production budget of 425 million dollars and the gross worldwide earnings from the movie were 2.7 billion dollars. Though this might not be the only factor for these high earnings, it is quite essential that a proper budget is set for Movie production.

# %% [markdown]
# ### 5.2. Recommendation based on Production Budget
# We can see that production budget of a movie is quite essential in determining the amount of earnings a Movie will make. For instance, the movie Avatar had a production budget of 425 million dollars and the worldwide gross earnings from the movie were 2.7 billion dollars. Though this might not be the only factor for these high earnings, it is quite essential that Microsoft sets aside a proper production budget should they venture into production of Movies.

# %% [markdown]
# Jurassic world has the least World wide gross earnings in the least of five. It has a production budget of 215 million dollars and the gross earnings of	1.6 billion dollars Microsoft should establish strategic partnerships with other media companies and platforms to expand reach and distribution also Invest significantly in content development, talent acquisition, and marketing.
#
# They can also Collaborate with established content creators and influencers to leverage their existing fanbases while
# implement robust feedback mechanisms to continuously improve content quality based on viewer responses.

# %% [markdown]
# For Avatar to stay on top they have to stay agile and adaptable to quickly respond to changing market dynamics and emerging trends.

# %% [markdown]
# Avengers: Infinity War	and Jurassic World Micrososft has to decide on a monetization strategy that balances the costs of content creation with revenue streams such as subscriptions or advertising also establish strategic partnerships with other media companies and platforms to expand reach and distribution.
